# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
N = 50
x = np.arange(N)
y = np.random.random(N)
plt.plot(x, y, 'g*:')
plt.show()

# %%
x = np.linspace(0, np.pi * 2, 100)
fig =plt.figure()
plt.title('Sine Cosine wave')
plt.plot(x, np.sin(x), 'r-', label ='Sine')
plt.plot(x, np.cos(x), 'b:', label ='Cosine')
plt.xlabel('x value')
plt.ylabel('y value')
plt.legend(loc='upper right')
plt.legend()
fig.savefig('sin_cos_fig.pdf')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig, ax = plt.subplots(2, 2)

X = np.random.randn(100)
Y = np.random.randn(100)
ax[0,0].scatter(X, Y)
X = np.arange(10)
Y = np.random.uniform(1, 10, 10)
ax[0, 1].bar(X , Y)
X = np.linspace(0 , 10, 100)
Y = np.cos(X)
ax[1, 0].plot(X, Y)
Z = np.random.uniform(0, 1, (5, 5))
ax[1, 1].imshow(Z)

# %%
x = np.arange(3)
years = ['2010', '2011', '2012']
domestic = [6801, 7695, 8010]
foreign = [777, 1046, 1681]

plt.bar(x, domestic, width=0.25)
plt.bar(x + 0.3, foreign, width=0.25)
plt.xticks(x, years)
# Out:
# ([<matplotlib.axis.XTick at 0x1d4698d1f90>,
# ...
#  [Text(0, 0, '2010'), Text(1, 0, '2011'), Text(2, 0, '2012')])

# %%
data = [5,4,6,11]
clist = ['cyan', 'gray','orange','red']
explode = [.06, .07, .08, .09]
plt.pie(data, autopct = '%.2f%%', colors=clist, labels=clist, explode=explode)
# Out:
# ([<matplotlib.patches.Wedge at 0x1d469a04b90>,
# ...
#  [Text(0.9546612794008222, 0.6589551135037842, 'cyan'),
#   Text(-0.141028023826564, 1.161469369589906, 'gray'),
#   Text(-1.1457113414559996, 0.28239249646386466, 'orange'),
#   Text(0.2847857680019063, -1.1554207313111378, 'red')],
#  [Text(0.5431693486246058, 0.3749227369935324, '19.23%'),
#   Text(-0.08075963757589562, 0.6651149381412284, '15.38%'),
#   Text(-0.6602404340593897, 0.16273465897917624, '23.08%'),
#   Text(0.1651278822868196, -0.6699498358022563, '42.31%')])

# %%
data = np.random.random((10,10))
plt.imshow(data)
plt.colorbar()

# %%
f1 = np.random.randn(100000)
plt.hist(f1, bins=200, color='red', alpha=.7, label='avg = 0. std = 1')
plt.axis([-8, 8, -2, 2500])
plt.legend()

# %%
X = np.linspace(0, 2*np.pi, 200)
Y = np.sin(X)
plt.figure(figsize=(4.2, 3.6))
plt.plot(X, Y)

# %%
import pandas as pd

# %%
a = [1, 2, None, 4]
np_a = np.array(a)
print(np_a)
# Out:
# [1 2 None 4]

# %%
se = pd.Series(a)
print(se)
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# 3    4.0
# dtype: float64

# %%
print(type(se))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(se[2])
# Out:
# nan

# %%
indexed_se = pd.Series(a, index=('a','b','c','d'))
print(indexed_se)
# Out:
# a    1.0
# b    2.0
# c    NaN
# d    4.0
# dtype: float64

# %%
print(indexed_se['a'], indexed_se['b'])
# Out:
# 1.0 2.0

# %%
income = {"1월": 9500, '2월':6200, "3월": 6050, '4월':7000}
income_se = pd.Series(income)
print("가게매출")
print(income_se)
# Out:
# 가게매출
# 1월    9500
# 2월    6200
# 3월    6050
# 4월    7000
# dtype: int64

# %%
print(income_se['1월'])
# Out:
# 9500

# %%
month_se = pd.Series(['1월', '2월', '3월', '4월'])
income_se = pd.Series([9500, 6200, 6050, 7000])
expenses_se = pd.Series([5040, 2350, 2300, 4800])
df = pd.DataFrame({'월': month_se, '수익': income_se, '지출' : expenses_se})
df
# Out:
#     월    수익    지출
# 0  1월  9500  5040
# 1  2월  6200  2350
# 2  3월  6050  2300
# 3  4월  7000  4800

# %%
df.iloc[0,1]
# Out:
# np.int64(9500)

# %%
income_se.max()
# Out:
# np.int64(9500)

# %%
print(income_se.mean())
# Out:
# 7187.5

# %%
file = 'https://github.com/dongupak/DataML/raw/main/csv/vehicle_prod.csv'
df = pd.read_csv(file)

# %%
print(df)
# Out:
#   Unnamed: 0   2007   2008   2009   2010   2011
# 0      China   7.71   7.95  11.96  15.84  16.33
# 1         EU  19.02  17.71  15.00  16.70  17.48
# 2         US  10.47   8.45   5.58   7.60   8.40
# 3      Japan  10.87  10.83   7.55   9.09   7.88
# 4      Korea   4.04   3.78   3.45   4.20   4.62
# 5     Mexico   2.01   2.05   1.50   2.25   2.54

# %%
df = pd.read_csv(file, index_col=0)
print(df)
# Out:
#          2007   2008   2009   2010   2011
# China    7.71   7.95  11.96  15.84  16.33
# EU      19.02  17.71  15.00  16.70  17.48
# US      10.47   8.45   5.58   7.60   8.40
# Japan   10.87  10.83   7.55   9.09   7.88
# Korea    4.04   3.78   3.45   4.20   4.62
# Mexico   2.01   2.05   1.50   2.25   2.54

# %%
column_list = df.columns
# Out:
# China      7.71
# EU        19.02
# US        10.47
# Japan     10.87
# Korea      4.04
# Mexico     2.01
# Name: 2007, dtype: float64

# %%
df['total'] = df.sum(axis=1)
print(df)
# Out:
#          2007   2008   2009   2010   2011  total
# China    7.71   7.95  11.96  15.84  16.33  59.79
# EU      19.02  17.71  15.00  16.70  17.48  85.91
# US      10.47   8.45   5.58   7.60   8.40  40.50
# Japan   10.87  10.83   7.55   9.09   7.88  46.22
# Korea    4.04   3.78   3.45   4.20   4.62  20.09
# Mexico   2.01   2.05   1.50   2.25   2.54  10.35

# %%
df['Mean'] = df[['2007', '2008', '2009', '2010', '2011']].mean(axis=1)

# %%
print(df)
# Out:
#          2007   2008   2009   2010   2011  total    Mean
# China    7.71   7.95  11.96  15.84  16.33  59.79  11.958
# EU      19.02  17.71  15.00  16.70  17.48  85.91  17.182
# US      10.47   8.45   5.58   7.60   8.40  40.50   8.100
# Japan   10.87  10.83   7.55   9.09   7.88  46.22   9.244
# Korea    4.04   3.78   3.45   4.20   4.62  20.09   4.018
# Mexico   2.01   2.05   1.50   2.25   2.54  10.35   2.070

# %%
new_df = df.drop('2007', axis= 1)
print(new_df)
# Out:
#          2008   2009   2010   2011  total    Mean
# China    7.95  11.96  15.84  16.33  59.79  11.958
# EU      17.71  15.00  16.70  17.48  85.91  17.182
# US       8.45   5.58   7.60   8.40  40.50   8.100
# Japan   10.83   7.55   9.09   7.88  46.22   9.244
# Korea    3.78   3.45   4.20   4.62  20.09   4.018
# Mexico   2.05   1.50   2.25   2.54  10.35   2.070

# %%
print(df)
# Out:
#          2007   2008   2009   2010   2011  total    Mean
# China    7.71   7.95  11.96  15.84  16.33  59.79  11.958
# EU      19.02  17.71  15.00  16.70  17.48  85.91  17.182
# US      10.47   8.45   5.58   7.60   8.40  40.50   8.100
# Japan   10.87  10.83   7.55   9.09   7.88  46.22   9.244
# Korea    4.04   3.78   3.45   4.20   4.62  20.09   4.018
# Mexico   2.01   2.05   1.50   2.25   2.54  10.35   2.070

# %%
new_df['total'] = new_df[['2008', '2009','2010','2011']].sum(axis=1)
df['mean'] = df[['2008', '2009', '2010', '2011']].mean(axis=1)
print(df)
# Out:
#          2007   2008   2009   2010   2011  total    Mean     mean
# China    7.71   7.95  11.96  15.84  16.33  59.79  11.958  13.0200
# EU      19.02  17.71  15.00  16.70  17.48  85.91  17.182  16.7225
# US      10.47   8.45   5.58   7.60   8.40  40.50   8.100   7.5075
# Japan   10.87  10.83   7.55   9.09   7.88  46.22   9.244   8.8375
# Korea    4.04   3.78   3.45   4.20   4.62  20.09   4.018   4.0125
# Mexico   2.01   2.05   1.50   2.25   2.54  10.35   2.070   2.0850

# %%
(f, ax) = plt.subplots(nrows=1, cnols=2, figsize(10,5))
# Out:
#   Cell In[1], line 1
#     (f, ax) = plt.subplots(nrows=1, cnols=2, figsize(10,5))
#                                                           ^
# SyntaxError: positional argument follows keyword argument
